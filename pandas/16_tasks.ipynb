# %%
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### `Q-1:` Write a program to create an empty series.

# %%
# code here
empty = pd.Series()

empty
# Out:
# Series([], dtype: object)

# %% [markdown]
# ### `Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here

a = pd.Series([1, 2, 3, 4, 5])
b = pd.Series([1, 2, 3, 4, 5])

add = a+b

sub = a-b

mul = a*b

divide = a/b

# %% [markdown]
# ### `Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here

a = pd.Series([2, 4, 6, 8, 10])
b = pd.Series([1, 3, 5, 7, 10])
a==b

a[a==b]        # 10 is commmon in both
# Out:
# 4    10
# dtype: int64

# %% [markdown]
# ### `Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here
import pandas as pd

def change_dtype(series, dtype):
    if dtype == float:
        return pd.to_numeric(series, errors="coerce")
    else:
        return series.astype(dtype)

series = pd.Series([1, 2, "Python", 2.0, True, 100])

result = change_dtype(series, float)

print(result)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %%
s = pd.read_csv('data/16_data/batsman_runs_ipl.csv', index_col=["batter"]).squeeze()
s
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           161
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yash Dayal           0
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_run, Length: 605, dtype: int64

# %% [markdown]
# ### `Q-6` Find top 10 most run getter from the series.

# %%
# code here
s.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ### `Q-7` No of players having runs above 3000

# %%
# code here

s[s>3000].size
# Out:
# 20

# %%
s[s>3000].shape[0]
# Out:
# 20

# %% [markdown]
# ### `Q-8` No of players having runs above mean value?

# %%
# code here
s[s>s.mean()].size
# Out:
# 128

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ### `Q-9`
# - i. Read `items.csv` making `item_name` as index.
# - ii. Show no of nan values
# - ii. Item price is given in $, so convert it to rupees without currency symbol.
# - iii. Make data type of newly made series as float.
# - iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# code here
item = pd.read_csv("data/16_data/items.csv", index_col=["item_name"]).squeeze()

# %%
item[item.notnull()].size
# Out:
# 4572

# %%
item = item.str.replace("$", "").astype(float)*277.85
item.head(2)
# Out:
# item_name
# Chips and Fresh Tomato Salsa    664.0615
# Izze                            941.9115
# Name: item_price, dtype: float64

# %%
item.fillna(item.mean(), inplace=True)
# Out:
# item_name
# Chips and Fresh Tomato Salsa              664.0615
# Izze                                      941.9115
# Nantucket Nectar                          941.9115
# Chips and Tomatillo-Green Chili Salsa     664.0615
# Chicken Bowl                             4717.8930
#                                            ...
# Steak Burrito                            3264.7375
# Steak Burrito                            3264.7375
# Chicken Salad Bowl                       3125.8125
# Chicken Salad Bowl                       2431.1875
# Chicken Salad Bowl                       2431.1875
# Name: item_price, Length: 4622, dtype: float64

# %%
item.isnull().sum()
# Out:
# np.int64(0)

# %%
item.shape
# Out:
# (4622,)

# %% [markdown]
# ### `Q-10`:
#    -  i. Find mean price
#    -  ii. Find 30th and 6th percentile value
#    -  iii. Plot Histogram on price with bin size 50
#    -  iv. No of items price lies between [1000 to 2000]

# %%
# code here
item.mean()
# Out:
# np.float64(2073.6033011811023)

# %%
np.percentile(item, [30, 6])
# Out:
# array([1236.4325,  347.3125])

# %%
item.max()
# Out:
# 12294.862500000001

# %%
item.plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
item[item.between(1000, 2000)].shape[0]
# Out:
# 555
