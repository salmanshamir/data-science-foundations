# %% [markdown]
# ### `Problem-1:` Class inheritence
#
# Create a **Bus** child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
# Write code here
class Vehicle:
    def __init__(self, seats):
        self.seats = seats
        
    def fare(self):
        charge = self.seats*100
        return charge
    

class Bus(Vehicle):
    def __init__(self):
        super().__init__(50)
        
    def fare(self):
        charge = super().fare()
        tax = charge*10/100
        return charge+tax
    
class Car(Vehicle):
    def __init__(self):
        super().__init__(5)
        
        
bus = Bus()

bus.fare()

car = Car()

car.fare()
# Out:
# 500

# %% [markdown]
# ### `Problem-2:` Class Inheritence
#
# Create a Bus class that inherits from the Vehicle class. Give the capacity argument of *Bus.seating_capacity()* a default value of 50.
#
# Use the following code for your parent Vehicle class.

# %%
# Write code here
class Vehicle:
    def __init__(self):
        self.seats = 50
        
    def fare(self):
        charge = self.seats*100
        return charge
    
    def seating_capacity(self, seatsss=50):
        self.seats = seatsss
    
class Bus(Vehicle):
    def __init__(self):
        super().__init__()
        
        
    def fare(self):
        charge = super().fare()
        tax = charge*10/100
        return charge + tax
        
        
        
bus = Bus()

bus.fare()

bus.seating_capacity(19)

bus.fare()
# Out:
# 2090.0

# %% [markdown]
# ### `Problem-3:` Write a program that has a class Point. Define another class Location which has two objects (Location & Destination) of class Point. Also define a function in Location that prints the reflection of Destination on the x axis.

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
        
class Location:
    def __init__(self, origin, destination):
        self.origin_x = origin.x
        self.origin_y = origin.y
        self.destination_x = destination.x
        self.destination_y = destination.y
        
    def reflection(self):
        return f"({self.destination_x}, {-self.destination_y})"
    

origin = Point(3, 5)
destination = Point(4, 6)

location = Location(origin , destination)
        
location.reflection()
# Out:
# '(4, -6)'

# %% [markdown]
# ### `Problem-4:` Write a program that has an abstract class Polygon. Derive two classes Rectangle and Triamgle from Polygon and write methods to get the details of their dimensions and hence calculate the area.

# %%
from abc import ABC, abstractmethod

class Polygon(ABC):
    @abstractmethod
    def get_dimension(self):
        pass
    
    @abstractmethod
    def area(self):
        pass
    
    

class Rectangle(Polygon):
    def __init__(self):
        self.lenght = 0
        self.width = 0
        
    def get_dimension(self, length, width):
        self.lenght = length
        self.width = width
        
    def area(self):
        are = self.lenght*self.width
        return are
    
class Triangle(Polygon):
    def __init__(self):
        self.base = 0
        self.height = 0
        
    def get_dimension(self, base, height):
        self.base = base
        self.height = height
        
    def area(self):
        are = 1/2*(self.base*self.height)
        return are
# Out:
# 12

# %% [markdown]
# ### `Problem-5:` Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %%
# code here

class Bill:
    def __init__(self):
        self.bill = 2000
        

class Cheque(Bill):
    def __init__(self):
        super().__init__()
        print(f"Your bill is {self.bill}")
        
    def pay(self, bankNo):
        print(f"YOu successfully pay the bill on accunt {bankNo}")
        
        
class Cash(Bill):
    def __init__(self):
        super().__init__()
        print(f"Your bill is {self.bill}")   
        
    def pay(self, amount):
        if amount<self.bill:
            print("please match your amount with bill")
        elif amount==self.bill:
            print("You successfullly pay the amont ")
        elif amount>self.bill:
            remaining = amount-self.bill
            print(f"Please take the remaining {remaining} amount")
             

ch = Cheque()

ch.pay(2334)

cash = Cash()

cash.pay(2001)
# Out:
# Your bill is 2000
# YOu successfully pay the bill on accunt 2334
# Your bill is 2000
# Please take the remaining 1 amount

# %% [markdown]
# ### `Q-6:` FlexibleDict
# As of now we are accessing values from dictionary with exact keys. Now we want to amend accessing values functionality. if a dict have key `1` (int) the even if we try to access values by giving `'1'` (1 as str) as key, we should get the same result and vice versa.
#
# Write a class `FlexibleDict` upon builtin `dict` class with above required functionality.
#
# Hint- `dict[key] => dict.__getitem__(key)`

# %% [markdown]
# Ex.
# ```
# fd = FlexibleDict()
# fd['a'] = 100
# print(fd['a']) # Like regular dict
#
# fd[5] = 500
# print(fd[5]) # Like regular dict
#
# fd[1] = 100
# print(fd['1']) # actual Key is int but still trying to access through str key.
# fd['1'] = 100
# print(fd[1])
#
# ```
# `Output:`
# ```
# 100
# 500
# 100
# 100
#
# ```

# %%
class FlexibleDict(dict):
    def __getitem__(self, key):
        if type(key)==str:
            if key.isdigit():
                if int(key) in self:
                    return self.get(int(key))
                elif str(key) in self:
                    return self.get(str(key))
            elif not key.isdigit():
                return self.get(str(key))
        elif type(key)==int:
            if int(key) in self:
                return self.get(int(key))
            elif str(key) in self:
                return self.get(str(key))


a = FlexibleDict()

# %%
a["1"] = "salman"
a[1]
# Out:
# 'salman'

# %%
a["1"]
# Out:
# 'salman'

# %%
a[2]="salman"

# %%
a["name"]="khan"

# %%
a["name"]
# Out:
# 'khan'
